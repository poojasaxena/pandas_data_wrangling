# %% [markdown]
# <a href="https://colab.research.google.com/github/poojasaxena/pandas_data_wrangling/blob/master/timeseries_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # upload dataset

# %%
! wget https://raw.githubusercontent.com/statsmodels/statsmodels/main/statsmodels/datasets/macrodata/macrodata.csv
# Out:
# --2022-06-26 09:04:31--  https://raw.githubusercontent.com/statsmodels/statsmodels/main/statsmodels/datasets/macrodata/macrodata.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17829 (17K) [text/plain]
# Saving to: ‘macrodata.csv.1’
#
# macrodata.csv.1     100%[===================>]  17.41K  --.-KB/s    in 0.001s
#
# 2022-06-26 09:04:31 (33.0 MB/s) - ‘macrodata.csv.1’ saved [17829/17829]

# %%
data = pd.read_csv('macrodata.csv.1')

# %%
data.head()
# Out:
#    year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959        1  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959        2  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959        3  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959        4  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960        1  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
periods=pd.PeriodIndex(year=data.year, quarter=data.quarter, name='date')
periods
# Out:
# PeriodIndex(['1959Q1', '1959Q2', '1959Q3', '1959Q4', '1960Q1', '1960Q2',
#              '1960Q3', '1960Q4', '1961Q1', '1961Q2',
#              ...
#              '2007Q2', '2007Q3', '2007Q4', '2008Q1', '2008Q2', '2008Q3',
#              '2008Q4', '2009Q1', '2009Q2', '2009Q3'],
#             dtype='period[Q-DEC]', name='date', length=203)

# %%
columns=pd.Index(['realgdp','infl','unemp'], name='item')
columns
# Out:
# Index(['realgdp', 'infl', 'unemp'], dtype='object', name='item')

# %%
data = data.reindex(columns=columns)
data.head()
# Out:
# item   realgdp  infl  unemp
# 0     2710.349  0.00    5.8
# 1     2778.801  2.34    5.1
# 2     2775.488  2.74    5.3
# 3     2785.204  0.27    5.6
# 4     2847.699  2.31    5.2

# %%
data.index = periods.to_timestamp('D','end')
data.index
# Out:
# DatetimeIndex(['1959-03-31 23:59:59.999999999',
#                '1959-06-30 23:59:59.999999999',
#                '1959-09-30 23:59:59.999999999',
#                '1959-12-31 23:59:59.999999999',
#                '1960-03-31 23:59:59.999999999',
#                '1960-06-30 23:59:59.999999999',
#                '1960-09-30 23:59:59.999999999',
#                '1960-12-31 23:59:59.999999999',
#                '1961-03-31 23:59:59.999999999',
#                '1961-06-30 23:59:59.999999999',
#                ...
#                '2007-06-30 23:59:59.999999999',
#                '2007-09-30 23:59:59.999999999',
#                '2007-12-31 23:59:59.999999999',
#                '2008-03-31 23:59:59.999999999',
#                '2008-06-30 23:59:59.999999999',
#                '2008-09-30 23:59:59.999999999',
#                '2008-12-31 23:59:59.999999999',
#                '2009-03-31 23:59:59.999999999',
#                '2009-06-30 23:59:59.999999999',
# ...

# %%
data.head()
# Out:
# item                            realgdp  infl  unemp
# date
# 1959-03-31 23:59:59.999999999  2710.349  0.00    5.8
# 1959-06-30 23:59:59.999999999  2778.801  2.34    5.1
# 1959-09-30 23:59:59.999999999  2775.488  2.74    5.3
# 1959-12-31 23:59:59.999999999  2785.204  0.27    5.6
# 1960-03-31 23:59:59.999999999  2847.699  2.31    5.2

# %%
data.stack().reset_index().rename(columns={0:'value'})
# Out:
#                              date     item      value
# 0   1959-03-31 23:59:59.999999999  realgdp   2710.349
# 1   1959-03-31 23:59:59.999999999     infl      0.000
# 2   1959-03-31 23:59:59.999999999    unemp      5.800
# 3   1959-06-30 23:59:59.999999999  realgdp   2778.801
# 4   1959-06-30 23:59:59.999999999     infl      2.340
# ..                            ...      ...        ...
# 604 2009-06-30 23:59:59.999999999     infl      3.370
# 605 2009-06-30 23:59:59.999999999    unemp      9.200
# 606 2009-09-30 23:59:59.999999999  realgdp  12990.341
# 607 2009-09-30 23:59:59.999999999     infl      3.560
# 608 2009-09-30 23:59:59.999999999    unemp      9.600
#
# [609 rows x 3 columns]

# %% [markdown]
# ## Long format for multiple time Series

# %%
ldata = data.stack().reset_index().rename(columns={0:'value'})
ldata[:3]
# Out:
#                            date     item     value
# 0 1959-03-31 23:59:59.999999999  realgdp  2710.349
# 1 1959-03-31 23:59:59.999999999     infl     0.000
# 2 1959-03-31 23:59:59.999999999    unemp     5.800
